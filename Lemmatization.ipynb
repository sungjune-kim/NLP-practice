# %%
from nltk.stem import WordNetLemmatizer

n = WordNetLemmatizer()
words = ['policy', 'doing', ' organization', 'have', 'going', 'love', 'watched']
print([n.lemmatize(w) for w in words])
# Out:
# ['policy', 'doing', ' organization', 'have', 'going', 'love', 'watched']

# %%
n.lemmatize('dies','v')
# Out:
# 'die'
