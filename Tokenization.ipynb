# %%
from nltk.tokenize import word_tokenize

text = "Don't look back in anger."
print(word_tokenize(text))
# Out:
# ['Do', "n't", 'look', 'back', 'in', 'anger', '.']

# %%
from nltk.tokenize import WordPunctTokenizer

print(WordPunctTokenizer().tokenize(text))
# Out:
# ['Don', "'", 't', 'look', 'back', 'in', 'anger', '.']

# %%
from tensorflow.keras.preprocessing.text import text_to_word_sequence

print(text_to_word_sequence(text))
# Out:
# ["don't", 'look', 'back', 'in', 'anger']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
text="Starting a home-based restaurant may be an ideal. it doesn't have a food chain or restaurant of their own."

print(tokenizer.tokenize(text))
# Out:
# ['Starting', 'a', 'home-based', 'restaurant', 'may', 'be', 'an', 'ideal.', 'it', 'does', "n't", 'have', 'a', 'food', 'chain', 'or', 'restaurant', 'of', 'their', 'own', '.']

# %%
from nltk.tokenize import sent_tokenize

text = "Some massive transfers happened this summer. Leo Messi left Barcelona and settled in Paris. Cristiano Ronaldo returned to Manchester United after 9 years since he left the club."
print(sent_tokenize(text))
# Out:
# ['Some massive transfers happened this summer.', 'Leo Messi left Barcelona and settled in Paris.', 'Cristiano Ronaldo returned to Manchester United after 9 years since he left the club.']

# %%
text = "Ph.d. students need to submit mail to realsjkim@gmail.com"
print(sent_tokenize(text))
# Out:
# ['Ph.d. students need to submit mail to realsjkim@gmail.com']
